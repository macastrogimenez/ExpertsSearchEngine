# %%
import pandas as pd

df = pd.read_csv("drp_combined.csv")

df.head()
# Out:
#                                                                                               abstract  \
# 0  Understanding software systems is a vital task, often undertaken by teams of engineers, for the ...
# 1  Comprehending existing software systems is an activity relevant for, e.g., preparing the re-engi...
# 2  Comprehending large-scale software systems is a challenging and daunting task, particularly when...
# 3  Exploring and comprehending a software system, e.g., as preparation for its re-engineering, is a...
# 4  Software visualization facilitates the interactive exploration of large-scale code bases, e.g., ...
#
#    author_count  \
# 0             4
# 1             1
# 2             3
# 3             4
# 4             3
#
#                                                               contributors  \
# 0  ['Hoff, Adrian', 'Lungu, Mircea', 'Seidl, Christoph', 'Lanza, Michele']
# 1                                                         ['Hoff, Adrian']
# ...

# %%
# Shape: publications × columns
df.shape
# Out:
# (4901, 102)

# %%
df["source_file"].nunique()
# Out:
# 234

# %%
print("Shape:", df.shape)
print("Unique IDs:", df["id"].nunique())
print("Researcher files:", df["source_file"].nunique())
# Out:
# Shape: (4901, 102)
# Unique IDs: 4032
# Researcher files: 234

# %%
df["src"].value_counts(dropna=False).head(30)
# Out:
# src
# ['ITU IT University of Copenhagen']                                                                                                                3733
# ['AAU Aalborg University']                                                                                                                          153
# ['ITU IT University of Copenhagen', 'KU University of Copenhagen']                                                                                  132
# ['KU University of Copenhagen']                                                                                                                     128
# ['CBS Copenhagen Business School']                                                                                                                  125
# ['AAU Aalborg University', 'ITU IT University of Copenhagen']                                                                                       106
# ...
